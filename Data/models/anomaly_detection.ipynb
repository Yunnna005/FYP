# %% [markdown]
# # Anomaly Detection

# %%
import pandas as pd

# %%
fm_encoded = pd.read_csv('../features/fm_encoded.csv', index_col='user_id')
transactions_df = pd.read_csv('../features/transactions_enriched.csv', parse_dates=['date'])

# %% [markdown]
# ## Feature Selection
#
# 1. Velocity Features: how fast the user spending
# 1. Amount Features: how large or unusual thier spend values are
# 1. Recency Features: how long since last activity
# 1. Merchant: new merchants
